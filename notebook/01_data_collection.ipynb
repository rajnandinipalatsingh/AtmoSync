# %%
import kagglehub
import shutil
import os


path = kagglehub.dataset_download("pratikjadhav05/indian-weather-data")

raw_path = r"C:\PlayGround\Infotact Data Analytics\AtmoSync\dataset\raw" #update the path 

os.makedirs(raw_path, exist_ok=True)

for file_name in os.listdir(path):
    source = os.path.join(path, file_name)
    destination = os.path.join(raw_path, file_name)

    if os.path.isfile(source):
        shutil.copy2(source, destination)

print("Dataset saved to:", os.path.abspath(raw_path))
# Out:
# ...
# 100%|██████████| 5.58M/5.58M [00:02<00:00, 2.27MB/s]
# Extracting files...
# Dataset saved to: C:\PlayGround\Infotact Data Analytics\AtmoSync\dataset\raw
